# %%
__author__="William Huanshan Chuang"
__version__="1.0.1"
__email__="wchuang2@mail.sfsu.edu"

#define elementary functions
import math
import statistics
def Cartesian_complex_mul(numb1,numb2):
    #numb1 a+bi, [a,b], numb2 c+di, [c,d]
    x=numb1[0]*numb2[0]-numb1[1]*numb2[1]
    y=numb1[0]*numb2[1]+numb1[1]*numb2[0]
    return [x,y]

def Cartesian_complex_scalar_mul(alpha,numb1):
    #numb1 a+bi, [a,b], numb2 c+di, [c,d]
    x=numb1[0]*alpha
    y=numb1[1]*alpha
    return [x,y]

def Cartesian_complex_add(numb1,numb2):
    #numb1 a+bi, [a,b], numb2 c+di, [c,d]
    x=numb1[0]+numb2[0]
    y=numb1[1]+numb2[1]
    return [x,y]

def Cartesian_complex_divide(numb1,numb2):
    #numb1 u+vi, [u,v], numb2 x+yi, [x,y]
    d=numb2[0]*numb2[0]+numb2[1]*numb2[1]
    nx=numb1[0]*numb2[0]+numb1[1]*numb2[1]
    ny=numb1[1]*numb2[0]-numb1[0]*numb2[1]
    X=float(nx/d)
    Y=float(ny/d)
    return[X,Y]

def Cartesian_complex_modulus(numb):
    return math.sqrt(numb[0]*numb[0]+numb[1]*numb[1])

def Cartesian_complex_complex_conjugate(numb):
    return [numb[0],-numb[1]]

def Cartesian_complex_complex_to_polar(numb):
    r=Cartesian_complex_modulus(numb)
    if numb[0]>0:
        t=math.atan(float(numb[1]/numb[0]))
    elif numb[0]<0:
        t=math.atan(float(numb[1]/numb[0]))+math.pi
    else:
        if numb[1]>0:
            t=float(math.pi/2)
        elif numb[1]<0:
            t=float(-math.pi/2)
        else:
            t="null"
    return [r,t]

def Polar_complex_complex_to_Cartesian(numb):
    return [numb[0]*math.cos(numb[1]),numb[0]*math.sin(numb[1])]

def Polar_complex_conjugate(numb):
    return [numb[0],-numb[1]]

def Polar_complex_mul(numb1,numb2):
    #numb1 r_1e^(it_1), [r_1,t_1], numb2 r_2e^(it_2), [r_2,t_2]
    r=numb1[0]*numb2[0]
    t=numb1[1]+numb2[1]
    return [r,t]

def Polar_complex_divide(numb1,numb2):
    #numb1 r_1e^(it_1), [r_1,t_1], numb2 r_2e^(it_2), [r_2,t_2]
    r=float(numb1[0]/numb2[0])
    t=numb1[1]-numb2[1]
    return [r,t]

def Polar_complex_add(numb1,numb2):
    N1=Polar_complex_complex_to_Cartesian(numb1)
    N2=Polar_complex_complex_to_Cartesian(numb2)
    tot=Cartesian_complex_add(N1,N2)
    return Cartesian_complex_complex_to_polar(tot)

def real_matrix_addition(m1,m2):
    #m1=[[M11,M12],[M21,M22]]
    a=m1[0][0]+m2[0][0]
    b=m1[0][1]+m2[0][1]
    c=m1[1][0]+m2[1][0]
    d=m1[1][1]+m2[1][1]
    l1=[a,b]
    l2=[c,d]
    l=[]
    l.append(l1)
    l.append(l2)
    return l

def Cartesian_complex_matrix_addition(m1,m2):
    #m1=[[M11,M12],[M21,M22]]
    #M11=[a,b]
    a1=m1[0][0][0]+m2[0][0][0]
    a2=m1[0][0][1]+m2[0][0][1]
    b1=m1[0][1][0]+m2[0][1][0]
    b2=m1[0][1][1]+m2[0][1][1]
    c1=m1[1][0][0]+m2[1][0][0]
    c2=m1[1][0][1]+m2[1][0][1]
    d1=m1[1][1][0]+m2[1][1][0]
    d2=m1[1][1][1]+m2[1][1][1]
    a=[a1,a2]
    b=[b1,b2]
    c=[c1,c2]
    d=[d1,d2]
    l1=[a,b]
    l2=[c,d]
    l=[]
    l.append(l1)
    l.append(l2)
    return l

def real_matrix_multiplication(m1,m2):
    #m1=[[M11,M12],[M21,M22]]
    a=m1[0][0]*m2[0][0]+m1[0][1]*m2[1][0]
    b=m1[0][0]*m2[0][1]+m1[0][1]*m2[1][1]
    c=m1[1][0]*m2[0][0]+m1[1][1]*m2[1][0]
    d=m1[1][0]*m2[0][1]+m1[1][1]*m2[1][1]
    l1=[a,b]
    l2=[c,d]
    l=[]
    l.append(l1)
    l.append(l2)
    return l

def Cartesian_complex_matrix_multiplication(m1,m2):
    #m1=[[M11,M12],[M21,M22]]
    #M11=[a,b]
    a=Cartesian_complex_add(Cartesian_complex_mul(m1[0][0],m2[0][0]),Cartesian_complex_mul(m1[0][1],m2[1][0])) 
    b=Cartesian_complex_add(Cartesian_complex_mul(m1[0][0],m2[0][1]),Cartesian_complex_mul(m1[0][1],m2[1][1])) 
    c=Cartesian_complex_add(Cartesian_complex_mul(m1[1][0],m2[0][0]),Cartesian_complex_mul(m1[1][1],m2[1][0])) 
    d=Cartesian_complex_add(Cartesian_complex_mul(m1[1][0],m2[0][1]),Cartesian_complex_mul(m1[1][1],m2[1][1])) 
    l1=[a,b]
    l2=[c,d]
    l=[]
    l.append(l1)
    l.append(l2)
    return l

def real_matrix_inverse(m1):
    #m1=[[M11,M12],[M21,M22]]
    det=m1[0][0]*m1[1][1]-m1[0][1]*m1[1][0]
    a=float(m1[1][1]/det)
    b=float(-m1[0][1]/det)
    c=float(-m1[1][0]/det)
    d=float(m1[0][0]/det)
    l1=[a,b]
    l2=[c,d]
    l=[]
    l.append(l1)
    l.append(l2)
    return l

def Cartesian_complex_matrix_inverse(m1):
    #m1=[[M11,M12],[M21,M22]]
    #M11=[a,b]
    det=Cartesian_complex_add(Cartesian_complex_mul(m1[0][0],m1[1][1]),Cartesian_complex_scalar_mul(-1,Cartesian_complex_mul(m1[0][1],m1[1][0])))   
    inverse_det=Cartesian_complex_divide([1,0],det)
    a=Cartesian_complex_mul(m1[1][1],inverse_det)
    b=Cartesian_complex_mul(Cartesian_complex_scalar_mul(-1,m1[0][1]),inverse_det) 
    c=Cartesian_complex_mul(Cartesian_complex_scalar_mul(-1,m1[1][0]),inverse_det) 
    d=Cartesian_complex_mul(m1[0][0],inverse_det)
    l1=[a,b]
    l2=[c,d]
    l=[]
    l.append(l1)
    l.append(l2)
    return l


def Cartesian_radial_hyperbolic_distance(z):
    r=float(Cartesian_complex_modulus(z))
    return math.log(float((1+r)/(1-r)))

def operator_T(Lambda):
    D=2
    a1=(-Lambda-float(1/Lambda))*float(-0.5)
    a2=0
    b1=0
    b2=(-Lambda+float(1/Lambda))*float(-0.5)
    c1=0
    c2=(Lambda-float(1/Lambda))*float(-0.5)
    d1=(-Lambda-float(1/Lambda))*float(-0.5)
    d2=0
    l1=[[a1,a2],[b1,b2]]
    l2=[[c1,c2],[d1,d2]]
    l=[]
    l.append(l1)
    l.append(l2)
    return l

def operator_R(theta):
    a=Polar_complex_complex_to_Cartesian([1,float(0.5*theta)])
    b=[0,0]
    c=[0,0]
    d=Polar_complex_complex_to_Cartesian([1,float(-0.5*theta)])
    l1=[a,b]
    l2=[c,d]
    l=[]
    l.append(l1)
    l.append(l2)
    return l

def classification_point(Lambda):
    return [float((2*Lambda**2)/(Lambda**4+1)),float((Lambda**4-1)/(Lambda**4+1))]

def check_T_generate_a_Schottky(Lambda,m):
    t=float(math.pi/2)-float(math.pi/(2*m))
    K=Polar_complex_complex_to_Cartesian([1,-t])
    B=classification_point(Lambda)
    T=operator_T(Lambda)
    T0=Cartesian_complex_divide(T[0][1],T[1][1])
    discriminant=float(Cartesian_complex_modulus(Cartesian_complex_add(K,Cartesian_complex_scalar_mul(-1,T0)))**2)-float(Cartesian_complex_modulus(Cartesian_complex_add(B,Cartesian_complex_scalar_mul(-1,T0)))**2) 
    print(discriminant)
    if discriminant>0:
        return True
    else:
        return False

def Tz(T,z):
    a=T[0][0][0]
    b=T[0][0][1]
    c=T[1][0][0]
    d=T[1][0][1]
    x=z[0]
    y=z[1]
    A=float(a*x+c-b*y)
    B=float(-d+b*x+a*y)
    C=float(c*x+a-d*y)
    D=float(-b+d*x+c*y)
    return [float((C*A+B*D)/(C**2+D**2)),float((B*C-D*A)/(C**2+D**2))]



#Generate the orbit Gamma(0)
def Gamma0(Lambda,m,N):
    T=operator_T(Lambda)
    theta=float(math.pi/m)
    R=operator_R(theta)
    L=[Tz(T,[0,0])]
    tmp1=[]
    tmp2=[]
    nodes_in_DT=[[0,0]]
    j=1
    while j<=N:
        #N=1
        if j==1:
            z=L[0]
            tmp1=[]
            tmp2=[]
            for i in range(2*m-1):
                z=Tz(R,z)
                tmp1.append(z)
                if i!=m-1:
                    tmp2.append(z)
                else:
                    tmp2.append(L[0])
            L=[]
            for k in tmp2:
                L.append(k)
            nodes_in_DT=[Tz(T,[0,0])]

        #N>1
        else:
            nodes_in_DT=[]
            tmp1=[]
            tmp2=[]
            tmp3=[]
            for k in L:
                z=Tz(T,k)
                nodes_in_DT.append(z)
                tmp1.append(z)
                tmp2.append(z)
            L=[]
            for i in range(2*m-1):
                if i!=m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                        L.append(k)
                    tmp3=[]
                elif i==m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                    tmp3=[]
                    for k in tmp2:
                        L.append(k)

        j+=1
    return nodes_in_DT
# measuring hyperbolic distance
def Hyperbolic_Distance_Gamma0(Lambda,m,N):
    T=operator_T(Lambda)
    theta=float(math.pi/m)
    R=operator_R(theta)
    L=[Tz(T,[0,0])]
    tmp1=[]
    tmp2=[]
    nodes_in_DT=[[0,0]]
    j=1
    while j<=N:
        #N=1
        if j==1:
            z=L[0]
            tmp1=[]
            tmp2=[]
            for i in range(2*m-1):
                z=Tz(R,z)
                tmp1.append(z)
                if i!=m-1:
                    tmp2.append(z)
                else:
                    tmp2.append(L[0])
            L=[]
            for k in tmp2:
                L.append(k)
            nodes_in_DT=[Tz(T,[0,0])]

        #N>1
        else:
            nodes_in_DT=[]
            tmp1=[]
            tmp2=[]
            tmp3=[]
            for k in L:
                z=Tz(T,k)
                nodes_in_DT.append(z)
                tmp1.append(z)
                tmp2.append(z)
            L=[]
            for i in range(2*m-1):
                if i!=m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                        L.append(k)
                    tmp3=[]
                elif i==m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                    tmp3=[]
                    for k in tmp2:
                        L.append(k)

        j+=1
    Hyperbolic_distance=[]
    for k in nodes_in_DT:
        Hyperbolic_distance.append(Cartesian_radial_hyperbolic_distance(k))
    return Hyperbolic_distance

# measuring Exp(-hyperbolic distance)
def Exp_negative_Hyperbolic_Distance_Gamma0(Lambda,m,N):
    T=operator_T(Lambda)
    theta=float(math.pi/m)
    R=operator_R(theta)
    L=[Tz(T,[0,0])]
    tmp1=[]
    tmp2=[]
    nodes_in_DT=[[0,0]]
    j=1
    while j<=N:
        #N=1
        if j==1:
            z=L[0]
            tmp1=[]
            tmp2=[]
            for i in range(2*m-1):
                z=Tz(R,z)
                tmp1.append(z)
                if i!=m-1:
                    tmp2.append(z)
                else:
                    tmp2.append(L[0])
            L=[]
            for k in tmp2:
                L.append(k)
            nodes_in_DT=[Tz(T,[0,0])]

        #N>1
        else:
            nodes_in_DT=[]
            tmp1=[]
            tmp2=[]
            tmp3=[]
            for k in L:
                z=Tz(T,k)
                nodes_in_DT.append(z)
                tmp1.append(z)
                tmp2.append(z)
            L=[]
            for i in range(2*m-1):
                if i!=m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                        L.append(k)
                    tmp3=[]
                elif i==m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                    tmp3=[]
                    for k in tmp2:
                        L.append(k)

        j+=1
    Hyperbolic_distance=[]
    for k in nodes_in_DT:
        Hyperbolic_distance.append(math.exp(-Cartesian_radial_hyperbolic_distance(k)))
    return Hyperbolic_distance

# measuring Exp(-hyperbolic distance)
def Improved_Exp_negative_Hyperbolic_Distance_Gamma0(Lambda,m,N,L):

    T=operator_T(Lambda)
    theta=float(math.pi/m)
    R=operator_R(theta)
    if len(L)==0:
        L=[Tz(T,[0,0])]
        j=1
    else:
        j=N
    tmp1=[]
    tmp2=[]
    nodes_in_DT=[[0,0]]
    
    while j<=N:
        #N=1
        if j==1:
            z=L[0]
            tmp1=[]
            tmp2=[]
            for i in range(2*m-1):
                z=Tz(R,z)
                tmp1.append(z)
                if i!=m-1:
                    tmp2.append(z)
                else:
                    tmp2.append(L[0])
            L=[]
            for k in tmp2:
                L.append(k)
            nodes_in_DT=[Tz(T,[0,0])]

        #N>1
        else:
            nodes_in_DT=[]
            tmp1=[]
            tmp2=[]
            tmp3=[]
            for k in L:
                z=Tz(T,k)
                nodes_in_DT.append(z)
                tmp1.append(z)
                tmp2.append(z)
            L=[]
            for i in range(2*m-1):
                if i!=m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                        L.append(k)
                    tmp3=[]
                elif i==m-1:
                    for k in tmp1:
                        tmp3.append(Tz(R,k))
                    tmp1=[]
                    for k in tmp3:
                        tmp1.append(k)
                    tmp3=[]
                    for k in tmp2:
                        L.append(k)

        j+=1
    Hyperbolic_distance=[]
    for k in nodes_in_DT:
        Hyperbolic_distance.append(math.exp(-Cartesian_radial_hyperbolic_distance(k)))
    return [Hyperbolic_distance,L]

def examples_of_10000(initial, increment):
    counter=initial
    useful_example=0
    while counter < initial+10000*increment:
        print("************"+str(counter)+"************")
        out=[]
        if check_T_generate_a_Schottky(Lambda=counter,m=2):
            try:
                rho=[]
                for i in range(15):
                    sum1=0
                    sum2=0
                    test=Exp_negative_Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=i)
                    ave_of_all_exp_of_negative_rho_of_this_level=statistics.mean(test)
                    occurence=0
                    tmp=[]
                    for node in test:
                        if node < ave_of_all_exp_of_negative_rho_of_this_level:
                            occurence+=1
                        else:
                            tmp.append(node)
                    print("N="+str(i))
                    print("occurence="+str(occurence))
                    if len(tmp)!=0:
                        ave_of_all_short_exp_of_negative_rho_of_this_level=statistics.mean(tmp)
                        rho.append(ave_of_all_short_exp_of_negative_rho_of_this_level)
                        print("ave_of_all_short_exp_of_negative_rho_of_this_level:"+str(ave_of_all_short_exp_of_negative_rho_of_this_level))
                        print("ave_of_all_exp_of_negative_rho_of_this_level:"+str(ave_of_all_exp_of_negative_rho_of_this_level))
                        if ave_of_all_short_exp_of_negative_rho_of_this_level!=0:
                            rho.append(ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level)
                            print("ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:"+str(ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level))
                        
            except:
                print("---")
        if len(rho)>2:
            if rho[-1]>1:        
                useful_example+=1
        
        counter+=increment
        print("counter:"+str(counter))
        print("useful_example:"+str(useful_example))

# %%
#Check whether the group generated by T is a Schottky group:
check_T_generate_a_Schottky(Lambda=0.3,m=2)
# Out:
# 0.462218862145
# True

# %%
Gamma0(Lambda=0.3,m=2,N=13)
# Out:
# [[0.22297892972659403, -0.9748232617213533],
#  [0.22297891745846038, -0.9748232661643681],
#  23.653575188793784,
#  24.165709880821957,
#  23.291744458358288,
#  22.64919935601823,
#  23.481113321115924,
#  22.93305191235861,
#  23.298150899185032,
#  23.963664226551515,
#  23.258825012789043,
#  22.56033110689203,
#  23.035256340172023,
#  22.11600704431833,
#  22.60927844121765,
#  23.528899150047593,
#  23.054272412106773,
#  23.753993555732436,
#  24.458963231018767,
#  23.79358299706293,
#  23.429483269795163,
#  23.977738326679024,
#  23.146054876557262,
#  23.793660752770094,
#  24.667742518920594,
#  24.155706559693204,
#  24.69352630443328,
#  25.380330104097546,
#  24.696962571894154,
#  24.188195516055057,
#  24.706558592391897,
#  23.839999917385484,
#  23.494590509560965,
#  24.33884802748276,
#  23.801473043866995,
#  24.2197181945928,
#  24.891999128998602,
#  24.19404142473624,
#  23.558544690413875,
#  24.048463825033124,
#  23.14767568795054,
#  23.758428817108598,
#  ...]

# %%
# Testing the number of nodes on the right of the average hyperbolic length 
# that is less than the average length is growing exponetially
# by checking the first reachable 13 levels.
import statistics
rho=[]
for i in range(15):
    test=Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=i)
    mid=statistics.mean(Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=i))
    first_occurence=1
    tmp=[]
    for node in test:
        if node > mid:
            print("N="+str(i))
            print("first_occurence="+str(first_occurence))
            break
        else:
            tmp.append(node)
        first_occurence+=1
    mid_right=statistics.mean(tmp)
    rho.append(mid_right)
    print("mid_right:"+str(mid_right))
    print("mid:"+str(mid))
    if mid_right!=0:
        print("mid/mid_right:"+str(mid/mid_right))
# Out:
# mid_right:0.0
# mid:0.0
# mid_right:2.40794560865
# mid:2.40794560865
# mid/mid_right:1.0
# N=2
# first_occurence=2
# mid_right:4.13862457561
# mid:4.36438012284
# mid/mid_right:1.05454844795
# N=3
# first_occurence=2
# mid_right:5.67195001367
# mid:6.3072654193
# mid/mid_right:1.11201005018
# N=4
# first_occurence=5
# mid_right:7.76484813131
# mid:8.24936368875
# mid/mid_right:1.06239858775
# N=5
# first_occurence=5
# mid_right:9.26161843177
# mid:10.1914195999
# mid/mid_right:1.10039294698
# N=6
# first_occurence=11
# mid_right:11.0594453834
# mid:12.1334733306
# mid/mid_right:1.09711408755
# N=7
# first_occurence=14
# mid_right:12.7593683622
# mid:14.0755269516
# mid/mid_right:1.10315233106
# N=8
# first_occurence=32
# mid_right:14.5077901544
# mid:16.0175805671
# mid/mid_right:1.10406756622
# N=9
# first_occurence=41
# mid_right:16.2123499341
# mid:17.959634182
# mid/mid_right:1.10777489105
# N=10
# first_occurence=95
# mid_right:17.9399576656
# mid:19.9016877871
# mid/mid_right:1.10934976315
# N=11
# first_occurence=122
# mid_right:19.6448570894
# mid:21.8437413312
# mid/mid_right:1.11193180137
# N=12
# first_occurence=284
# mid_right:21.3636787018
# mid:23.785794406
# mid/mid_right:1.11337540402
# N=13
# first_occurence=365
# mid_right:23.0683763298
# mid:25.7278441322
# mid/mid_right:1.11528630209
# N=14
# first_occurence=851
# mid_right:24.7835910635
# mid:27.6698684466
# mid/mid_right:1.11645920786

# %%
print(rho)
# Out:
# [0.0, 2.4079456086518727, 4.138624575609016, 5.671950013672767, 7.764848131306017, 9.261618431768401, 11.059445383367127, 12.759368362189964, 14.507790154391069, 16.21234993413757, 17.93995766555417, 19.644857089400496, 21.363678701779378, 23.06837632980037, 24.783591063511295]

# %%
for i in range(len(rho)):
    if i>1:
        print(rho[i]/rho[i-1])
# Out:
# 1.71873673589
# 1.37049155101
# 1.36899093126
# 1.19276234063
# 1.19411585187
# 1.15370779636
# 1.13703043462
# 1.11749272368
# 1.10656121651
# 1.09503363696
# 1.0874947374
# 1.07979419892
# 1.07435350929

# %%
# Testing the number of nodes on the right of the average hyperbolic length 
# that is less than the average length is growing exponetially
# by checking the first reachable 13 levels.
import statistics
import gc
for i in range(17):
    gc.collect()
    test=Exp_negative_Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=i)
    mid=statistics.mean(test)
    first_occurence=1
    for node in test:
        if node < mid:
            print("N="+str(i))
            print("first_occurence="+str(first_occurence))
            break
        first_occurence+=1
# Out:
# N=2
# first_occurence=2
# N=3
# first_occurence=2
# N=4
# first_occurence=4
# N=5
# first_occurence=5
# N=6
# first_occurence=5
# N=7
# first_occurence=14
# N=8
# first_occurence=14
# N=9
# first_occurence=32
# N=10
# first_occurence=41
# N=11
# first_occurence=95
# N=12
# first_occurence=122
# N=13
# first_occurence=122
# N=14
# first_occurence=365
# N=15
# first_occurence=365

# %%
test=Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=13)
x=[]
for i in range(len(test)):
    x.append(i)

# %%
# Testing the number of nodes on the right of the average hyperbolic length 
# that is less than the average length is growing exponetially
# by checking the first reachable 13 levels.
import statistics
import gc
L=[]
N=0
for i in range(15):
    gc.collect()
    result=Improved_Exp_negative_Hyperbolic_Distance_Gamma0(Lambda=0.45,m=2,N=i,L=L)
    #print(L)
    test=result[0]
    L=result[1]
    
    mid=statistics.mean(test)
    first_occurence=1
    for node in test:
        if node < mid:
            print("N="+str(i))
            print("first_occurence="+str(first_occurence))
            break
        first_occurence+=1
# Out:
# N=2
# first_occurence=2
# N=3
# first_occurence=2
# N=4
# first_occurence=4
# N=5
# first_occurence=5
# N=6
# first_occurence=11
# N=7
# first_occurence=13
# N=8
# first_occurence=14
# N=9
# first_occurence=32
# N=10
# first_occurence=41
# N=11
# first_occurence=92
# N=12
# first_occurence=122
# N=13
# first_occurence=284
# N=14
# first_occurence=365

# %%
# Testing the number of nodes on the right of the average hyperbolic length 
# that is less than the average length is growing exponetially
# by checking the first reachable 13 levels.
import statistics
rho=[]
for i in range(15):
    sum1=0
    sum2=0
    test=Exp_negative_Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=i)
    mid=statistics.mean(test)
    first_occurence=1
    tmp=[]
    
    for node in test:
        if node < mid:
            print("N="+str(i))
            print("first_occurence="+str(first_occurence))
            break
        else:
            tmp.append(node)
        first_occurence+=1
    if len(tmp)!=0:
        mid_right=statistics.mean(tmp)
        rho.append(mid_right)
        print("mid_right:"+str(mid_right))
        print("mid:"+str(mid))
        if mid_right!=0:
            print("mid_right/mid:"+str(mid_right/mid))
# Out:
# mid_right:1.0
# mid:1.0
# mid_right/mid:1.0
# mid_right:0.09
# mid:0.09
# mid_right/mid:1.0
# N=2
# first_occurence=2
# mid_right:0.0159447672511
# mid:0.0133298448341
# mid_right/mid:1.19617050683
# N=3
# first_occurence=2
# mid_right:0.00344114844276
# mid:0.00202773940053
# mid_right/mid:1.69703682922
# N=4
# first_occurence=4
# mid_right:0.000532738526258
# mid:0.000309445874762
# mid_right/mid:1.72158871618
# N=5
# first_occurence=5
# mid_right:0.00010472104427
# mid:4.72415608909e-05
# mid_right/mid:2.21671431457
# N=6
# first_occurence=5
# mid_right:2.38682537611e-05
# mid:7.21246710416e-06
# mid_right/mid:3.30930504311
# N=7
# first_occurence=14
# mid_right:3.45892030139e-06
# mid:1.10114841833e-06
# mid_right/mid:3.14119354287
# N=8
# first_occurence=14
# mid_right:7.90515620115e-07
# mid:1.68115656877e-07
# mid_right/mid:4.70221295745
# N=9
# first_occurence=32
# mid_right:1.39205066189e-07
# mid:2.56667274538e-08
# mid_right/mid:5.42356116259
# N=10
# first_occurence=41
# mid_right:2.70532676618e-08
# mid:3.91861720749e-09
# mid_right/mid:6.90377912139
# N=11
# first_occurence=95
# mid_right:4.82018003075e-09
# mid:5.98267199531e-10
# mid_right/mid:8.05690172305
# N=12
# first_occurence=122
# mid_right:9.37862026566e-10
# mid:9.13392830626e-11
# mid_right/mid:10.2678934531
# N=13
# first_occurence=122
# mid_right:2.14522309551e-10
# mid:1.39450587113e-11
# mid_right/mid:15.3833923536
# N=14
# first_occurence=365
# mid_right:3.26682845937e-11
# mid:2.12904756057e-12
# mid_right/mid:15.3440839927

# %%
for i in range(len(rho)):
    if i>1:
        print(rho[i-1]-rho[i])
# Out:
# 0.0740552327489
# 0.0125036188084
# 0.0029084099165
# 0.000428017481989
# 8.08527905085e-05
# 2.04093334597e-05
# 2.66840468127e-06
# 6.51310553925e-07
# 1.12151798528e-07
# 2.2233087631e-08
# 3.88231800418e-09
# 7.23339717016e-10
# 1.81854024957e-10

# %% [markdown]
# Sum([1,2])

# %%
# Testing the number of nodes on the right of the average hyperbolic length 
# that is less than the average length is growing exponetially
# by checking the first reachable 13 levels.
import statistics
rho=[]
for i in range(15):
    sum1=0
    sum2=0
    test=Exp_negative_Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=i)
    mid=statistics.mean(test)
    first_occurence=1
    tmp=[]
    
    for node in test:
        if node < mid:
            print("N="+str(i))
            print("first_occurence="+str(first_occurence))
            break
        else:
            tmp.append(node)
        first_occurence+=1
    if len(tmp)!=0:
        mid_right=statistics.mean(tmp)
        rho.append(mid_right)
        print("mid_right:"+str(mid_right))
        print("mid:"+str(mid))
        if mid_right!=0:
            print("mid_right/mid:"+str(mid_right/mid))
# Out:
# mid_right:1.0
# mid:1.0
# mid_right/mid:1.0
# mid_right:0.09
# mid:0.09
# mid_right/mid:1.0
# N=2
# first_occurence=2
# mid_right:0.0159447672511
# mid:0.0133298448341
# mid_right/mid:1.19617050683
# N=3
# first_occurence=2
# mid_right:0.00344114844276
# mid:0.00202773940053
# mid_right/mid:1.69703682922
# N=4
# first_occurence=4
# mid_right:0.000532738526258
# mid:0.000309445874762
# mid_right/mid:1.72158871618
# N=5
# first_occurence=5
# mid_right:0.00010472104427
# mid:4.72415608909e-05
# mid_right/mid:2.21671431457
# N=6
# first_occurence=5
# mid_right:2.38682537611e-05
# mid:7.21246710416e-06
# mid_right/mid:3.30930504311
# N=7
# first_occurence=14
# mid_right:3.45892030139e-06
# mid:1.10114841833e-06
# mid_right/mid:3.14119354287
# N=8
# first_occurence=14
# mid_right:7.90515620115e-07
# mid:1.68115656877e-07
# mid_right/mid:4.70221295745
# N=9
# first_occurence=32
# mid_right:1.39205066189e-07
# mid:2.56667274538e-08
# mid_right/mid:5.42356116259
# N=10
# first_occurence=41
# mid_right:2.70532676618e-08
# mid:3.91861720749e-09
# mid_right/mid:6.90377912139
# N=11
# first_occurence=95
# mid_right:4.82018003075e-09
# mid:5.98267199531e-10
# mid_right/mid:8.05690172305
# N=12
# first_occurence=122
# mid_right:9.37862026566e-10
# mid:9.13392830626e-11
# mid_right/mid:10.2678934531
# N=13
# first_occurence=122
# mid_right:2.14522309551e-10
# mid:1.39450587113e-11
# mid_right/mid:15.3833923536
# N=14
# first_occurence=365
# mid_right:3.26682845937e-11
# mid:2.12904756057e-12
# mid_right/mid:15.3440839927

# %%
check_T_generate_a_Schottky(Lambda=0.6,m=2)
# Out:
# 0.0597001999431
# True

# %%
# Testing the number of nodes on the right of the average hyperbolic length 
# that is less than the average length is growing exponetially
# by checking the first reachable 13 levels.
import statistics
rho=[]
for i in range(15):
    sum1=0
    sum2=0
    test=Exp_negative_Hyperbolic_Distance_Gamma0(Lambda=0.3,m=2,N=i)
    ave_of_all_exp_of_negative_rho_of_this_level=statistics.mean(test)
    occurence=0
    tmp=[]
    for node in test:
        if node < ave_of_all_exp_of_negative_rho_of_this_level:
            occurence+=1
        else:
            tmp.append(node)
    print("N="+str(i))
    print("occurence="+str(occurence))
    if len(tmp)!=0:
        ave_of_all_short_exp_of_negative_rho_of_this_level=statistics.mean(tmp)
        rho.append(ave_of_all_short_exp_of_negative_rho_of_this_level)
        print("ave_of_all_short_exp_of_negative_rho_of_this_level:"+str(ave_of_all_short_exp_of_negative_rho_of_this_level))
        print("ave_of_all_exp_of_negative_rho_of_this_level:"+str(ave_of_all_exp_of_negative_rho_of_this_level))
        if ave_of_all_short_exp_of_negative_rho_of_this_level!=0:
            print("ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:"+str(ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level))
# Out:
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214

# %%
examples_of_10000(0.3, 0.001)
# Out:
# ************0.3************
# 0.462218862145
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.301
# useful_example:1
# ************0.301************
# 0.461302850598
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.302
# useful_example:2
# ************0.302************
# 0.460382975828
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# ---
# counter:0.303
# useful_example:3
# ************0.303************
# 0.459459237217
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.304
# useful_example:4
# ************0.304************
# 0.458531634258
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.305
# useful_example:5
# ************0.305************
# 0.457600166556
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.306
# useful_example:6
# ************0.306************
# 0.456664833827
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.307
# useful_example:7
# ************0.307************
# 0.455725635903
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.308
# useful_example:8
# ************0.308************
# 0.454782572729
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.309
# useful_example:9
# ************0.309************
# 0.453835644364
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.31
# useful_example:10
# ************0.31************
# 0.452884850985
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.311
# useful_example:11
# ************0.311************
# 0.451930192885
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.312
# useful_example:12
# ************0.312************
# 0.450971670473
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ...
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.507
# useful_example:207
# ************0.507************
# 0.199690899585
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.508
# useful_example:208
# ************0.508************
# 0.198172510554
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# N=14
# occurence=1167440
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.87188581833e-12
# ave_of_all_exp_of_negative_rho_of_this_level:2.12904756057e-12
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.75798715214
# counter:0.509
# useful_example:209
# ************0.509************
# 0.196653351198
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
# ---
# counter:0.51
# useful_example:210
# ************0.51************
# 0.195133453562
# N=0
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_exp_of_negative_rho_of_this_level:1.0
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=1
# occurence=0
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_exp_of_negative_rho_of_this_level:0.09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.0
# N=2
# occurence=1
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0159447672511
# ave_of_all_exp_of_negative_rho_of_this_level:0.0133298448341
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.19617050683
# N=3
# occurence=5
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.0029339704203
# ave_of_all_exp_of_negative_rho_of_this_level:0.00202773940053
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.44691690635
# N=4
# occurence=15
# ave_of_all_short_exp_of_negative_rho_of_this_level:0.000466221221462
# ave_of_all_exp_of_negative_rho_of_this_level:0.000309445874762
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.50663253088
# N=5
# occurence=53
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.35028028991e-05
# ave_of_all_exp_of_negative_rho_of_this_level:4.72415608909e-05
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.76757078565
# N=6
# occurence=155
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.31730646819e-05
# ave_of_all_exp_of_negative_rho_of_this_level:7.21246710416e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.82642977661
# N=7
# occurence=467
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.10134220008e-06
# ave_of_all_exp_of_negative_rho_of_this_level:1.10114841833e-06
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:1.90831877439
# N=8
# occurence=1481
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.51496525845e-07
# ave_of_all_exp_of_negative_rho_of_this_level:1.68115656877e-07
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.09080184663
# N=9
# occurence=4493
# ave_of_all_short_exp_of_negative_rho_of_this_level:5.62835146972e-08
# ave_of_all_exp_of_negative_rho_of_this_level:2.56667274538e-08
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.19285901557
# N=10
# occurence=13591
# ave_of_all_short_exp_of_negative_rho_of_this_level:8.9512689861e-09
# ave_of_all_exp_of_negative_rho_of_this_level:3.91861720749e-09
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.28429277782
# N=11
# occurence=41693
# ave_of_all_short_exp_of_negative_rho_of_this_level:1.44803385559e-09
# ave_of_all_exp_of_negative_rho_of_this_level:5.98267199531e-10
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.42037981813
# N=12
# occurence=127003
# ave_of_all_short_exp_of_negative_rho_of_this_level:2.32155837862e-10
# ave_of_all_exp_of_negative_rho_of_this_level:9.13392830626e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.54168666621
# N=13
# occurence=384415
# ave_of_all_short_exp_of_negative_rho_of_this_level:3.68338898654e-11
# ave_of_all_exp_of_negative_rho_of_this_level:1.39450587113e-11
# ave_of_all_short_exp_of_negative_rho_of_this_level/ave_of_all_exp_of_negative_rho_of_this_level:2.64135781913
